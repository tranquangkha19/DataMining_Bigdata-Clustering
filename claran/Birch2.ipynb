# %%
from clarans import CLARANS
import numpy as np
import csv
import time
import matplotlib.pyplot as plt

# %%
data = []

# %%
with open('birch2.txt', 'r') as file:
    for line in file:
        tmp = []
        x1, x2 = line.split()
        val1, val2 = int(x1), int(x2)
        tmp.append(val1)
        tmp.append(val2)
        data.append(tmp)

# %%
x_axis = [point[0] for point in data]
y_axis = [point[1] for point in data]

# %%
plt.scatter(x_axis, y_axis, marker='o')

# %%
clarans_obj = CLARANS(data, 100, 1, 5)

# %%
start = time.time()
clarans_obj.process()
end = time.time()

# %%
clst = clarans_obj.clusters
med = clarans_obj.optimal_medoids
print(len(clst))
print(med)
print(end-start)
# Out:
# 100
# [16886, 31319, 13824, 43004, 17093, 87328, 99844, 92169, 76722, 16156, 13714, 5134, 82975, 68314, 39929, 43172, 19379, 51556, 83668, 14268, 48314, 49080, 88912, 68664, 83107, 14270, 34361, 6191, 72864, 43318, 97511, 17737, 14970, 619, 57348, 18168, 61360, 28516, 71175, 97284, 33595, 20000, 66227, 36480, 437, 69243, 12142, 72301, 52298, 80579, 65771, 78963, 1445, 11444, 99928, 73070, 23458, 38312, 13467, 27725, 16257, 96485, 21083, 80240, 3439, 9361, 42986, 83847, 96413, 4716, 99549, 72622, 26010, 72185, 87280, 73439, 29337, 38435, 10886, 30935, 1229, 8155, 92200, 81329, 79151, 37441, 70630, 82509, 38892, 33273, 25221, 10015, 63530, 7185, 65714, 40859, 93246, 49621, 39143, 51035]
# 64.93243956565857

# %%
for i in range(len(clst)):
    cluster = [data[idx] for idx in clst[i]]
    x_cluster = [point[0] for point in cluster]
    y_cluster = [point[1] for point in cluster]
    plt.scatter(x_cluster , y_cluster, label=i)
    plt.scatter(data[med[i]][0] , data[med[i]][1] , s = 30, color = 'k')
